# %% [markdown]
# # Imports, Loading Dataset for Q4 2018

# %%
import numpy as np
import pandas as pd
import pprint as pp
import matplotlib.pyplot as plt

# %%
data_num =pd.read_csv('2018q4/num.txt', sep='\t', encoding='ISO-8859-1')
data_sub =pd.read_csv('2018q4/sub.txt', sep='\t', encoding='ISO-8859-1')
data_tag =pd.read_csv('2018q4/tag.txt', sep='\t', encoding='ISO-8859-1')
data_pre =pd.read_csv('2018q4/pre.txt', sep='\t', encoding='ISO-8859-1')

# %% [markdown]
# # Inspecting Numerical Dataset

# %%
# pd.options.display.precison.set_option(3)
pd.set_option("display.precision", 3)
# pd.options.display.float_format = '${:.0f} million'.format
pd.reset_option("display.float_format")

# %%
data_num.shape
# Out:
# (2247296, 9)

# %%
data_num.sample(10)
# Out:
#                          adsh  \
# 1481021  0001144204-18-058165
# 112636   0001235468-18-000007
# 952896   0001175483-18-000013
# 2107319  0001021635-18-000104
# 1165783  0001171843-18-007912
# 320595   0001579241-18-000037
# 1032879  0001309402-18-000152
# 1052902  0000072741-18-000060
# 1115862  0001615774-18-012873
# 1768862  0000895126-18-000260
#
#                                                        tag  \
# 1481021                                  NoninterestIncome
# 112636                     EarningsPerShareBasicAndDiluted
# 952896   ComprehensiveIncomeNetOfTaxIncludingPortionAtt...
# 2107319      EquityinEarningsAmortizationofBasisDifference
# 1165783     EquityMethodInvestmentDividendsOrDistributions
# 320595                                          ProfitLoss
# 1032879           NetIncomeLossAttributableToParentDiluted
# 1052902           CapitalExpendituresIncurredButNotYetPaid
# 1115862                        ProceedsFromConvertibleDebt
# ...

# %%
# data_num.value = data_num.value.apply(lambda x: x/1_000_000)

# %%
data_num.iloc[2247294]
# Out:
# adsh                                     0000320193-18-000145
# tag         TaxCutsAndJobsActOf2017ReclassificationFromAoc...
# version                                  0000320193-18-000145
# coreg                                                     NaN
# ddate                                                20180930
# qtrs                                                        4
# uom                                                       USD
# value                                                     0.0
# footnote                                                  NaN
# Name: 2247294, dtype: object

# %% [markdown]
# # Next

# %%
data_pre.head()
# Out:
#                    adsh  report  line stmt  inpth rfile           tag  \
# 0  0000104918-18-000116       1     3   CP      0     H  EntityDomain
# 1  0000100517-18-000028       2     8   IS      0     H  EntityDomain
# 2  0000100517-18-000028       3     3   CI      0     H  EntityDomain
# 3  0000100517-18-000028       4     3   BS      0     H  EntityDomain
# 4  0000100517-18-000028       1     3   CP      0     H  EntityDomain
#
#     version           plabel  negating
# 0  dei/2014  Entity [Domain]         0
# 1  dei/2014  Entity [Domain]         0
# 2  dei/2014  Entity [Domain]         0
# 3  dei/2014  Entity [Domain]         0
# 4  dei/2014  Entity [Domain]         0

# %%
data_sub.sample(10)
# Out:
#                       adsh      cik                               name  \
# 1844  0000820027-18-000077   727892      RIVERSOURCE LIFE INSURANCE CO
# 6316  0001078782-18-001443  1543739                    APT SYSTEMS INC
# 219   0001193125-18-299303   862692        CRYO CELL INTERNATIONAL INC
# 5273  0001144204-18-060568  1072379      NORTHWEST BIOTHERAPEUTICS INC
# 6053  0001628280-18-014990  1705873               BERRY PETROLEUM CORP
# 5549  0000936528-18-000072   936528             WASHINGTON FEDERAL INC
# 4211  0001341318-18-000050  1341318           LAKE SHORE BANCORP, INC.
# 6032  0001206774-18-003390  1725206            UNION ACQUISITION CORP.
# 2945  0000860546-18-000041   860546  CORPORATE OFFICE PROPERTIES TRUST
# 1203  0001635261-18-000020  1635261                 MSB FINANCIAL CORP
#
#          sic countryba stprba         cityba  zipba  \
# 1844  6311.0        US     MN    MINNEAPOLIS  55474
# 6316  8742.0        US     CA  SAN FRANCISCO  94111
# ...

# %%
data_tag.head()
# Out:
#                        tag   version  custom  abstract  datatype iord crdr  \
# 0             EntityDomain  dei/2014       0         1    member  NaN  NaN
# 1          LegalEntityAxis  dei/2014       0         1      axis  NaN  NaN
# 2        EntityPublicFloat  dei/2014       0         0  monetary    I    C
# 3  DocumentFiscalYearFocus  dei/2014       0         0     gYear    D  NaN
# 4    DocumentPeriodEndDate  dei/2014       0         0      date    D  NaN
#
#                        tlabel  \
# 0             Entity [Domain]
# 1         Legal Entity [Axis]
# 2         Entity Public Float
# 3  Document Fiscal Year Focus
# 4    Document Period End Date
#
#                                                  doc
# 0  All the names of the entities being reported u...
# 1  The set of legal entities associated with a re...
# 2  State aggregate market value of voting and non...
# 3  This is focus fiscal year of the document repo...
# 4  The end date of the period reflected on the co...

# %%
pp.pprint(data_tag.doc[5])
# Out:
# 'End date of current fiscal year in the format --MM-DD.'
